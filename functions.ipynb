# %%
# usage of functions in python

# %%
student_master = {
    'Alice': {
        'age': 21,
        'major': 'Computer Science',
        'GPA': 3.8
    },
    'Bob': {
        'age': 22,
        'major': 'Mathematics',
        'GPA': 3.6
    },
    'Charlie': {
        'age': 20,
        'major': 'Physics',
        'GPA': 3.9
    },
    'Daniel': {
        'age': 23,
        'major': 'Chemistry',
        'GPA': 3.7
    }
}

# %%
# Conditions
major_condition = 'Chemistry'
gpa_condition = 3.5

# Check eligibility for Alice
if student_master['Alice']['major'] == major_condition:
    if student_master['Alice']['GPA'] > gpa_condition: # executes if above condition is true
        print("Alice is eligible for the scholarship.") # executes if above condition is true

# %%
if student_master['Bob']['major'] == major_condition:
    if student_master['Bob']['GPA'] > gpa_condition:
        print("Bob is eligible for the scholarship.")

# %%
# define the variable that can be replaced with the name of the student
student_name = 'Daniel'

# %%
if student_master[student_name]['major'] == major_condition:
    if student_master[student_name]['GPA'] > gpa_condition:
        print(f"{student_name} is eligible for the scholarship.")
# Out:
# Daniel is eligible for the scholarship.

# %% [markdown]
# ```
# def function_name(arguments):
#     code logic that needs to be executed
# ```

# %%
# we use functions when we want to reuse a block of code
# multiple times without having to rewrite it.
def check_scholarship_eligibility(student_name, mjr_cond, gpa_cond):
    """
    Check if a student is eligible for a scholarship based on their major and GPA.
    Parameters:
    student_name (str): The name of the student to check.
    mjr_cond (str): The major condition for eligibility.
    gpa_cond (float): The GPA condition for eligibility.
    Returns:
    None: Prints the eligibility status of the student.
    """
    if student_master[student_name]['major'] == mjr_cond:
        if student_master[student_name]['GPA'] > gpa_cond:
            print(f"{student_name} is eligible for the scholarship.")
        else:
            print(f"{student_name} is not eligible for the scholarship due to GPA.")
    else:
        print(f"{student_name} is not eligible for the scholarship due to major.")

# %%
type(check_scholarship_eligibility)
# Out:
# function

# %%
print(check_scholarship_eligibility.__doc__)
# Out:
# Check if a student is eligible for a scholarship based on their major and GPA.
# Parameters:
# student_name (str): The name of the student to check.
# mjr_cond (str): The major condition for eligibility.
# gpa_cond (float): The GPA condition for eligibility.
# Returns:
# None: Prints the eligibility status of the student.

# %%
check_scholarship_eligibility('Alice', major_condition, gpa_condition)
# Out:
# Alice is not eligible for the scholarship due to major.

# %%
check_scholarship_eligibility('Daniel', major_condition, gpa_condition)
# Out:
# Daniel is eligible for the scholarship.

# %%
# wild cards
def get_total_value(a, b):
    return a+b

# %%
get_total_value(10, 20)
# Out:
# 30

# %%
get_total_value(10, 20, 30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_total_value(10, 20, 30)
#
# TypeError: get_total_value() takes 2 positional arguments but 3 were given

# %%
get_total_value(20, 10)
# Out:
# 30

# %%
# wild cards
def get_total_value_wc(*args):
    for arg in args:
        print(arg)
    return sum(args)

# %%
get_total_value_wc(1, 2, 5, 10, 14, 20, 500)
# Out:
# 1
# 2
# 5
# 10
# 14
# 20
# 500
# 552

# %%
# key word arguments
def check_scholarship_eligibility_new(student_name, mjr_cond='Chemistry', gpa_cond=4):
    """
    Check if a student is eligible for a scholarship based on their major and GPA.
    Parameters:
    student_name (str): The name of the student to check.
    mjr_cond (str): The major condition for eligibility.
    gpa_cond (float): The GPA condition for eligibility.
    Returns:
    None: Prints the eligibility status of the student.
    """
    if student_master[student_name]['major'] == mjr_cond:
        if student_master[student_name]['GPA'] > gpa_cond:
            print(f"{student_name} is eligible for the scholarship.")
        else:
            print(f"{student_name} is not eligible for the scholarship due to GPA.")
    else:
        print(f"{student_name} is not eligible for the scholarship due to major.")

# %%
check_scholarship_eligibility_new('Bob', gpa_cond=3.5, mjr_cond='Mathematics')
# Out:
# Bob is eligible for the scholarship.

# %%
check_scholarship_eligibility_new('Bob')
# Out:
# Bob is not eligible for the scholarship due to major.

# %%
# wild cards with key word arguments
def wild_card_kw(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

# %%
wild_card_kw(name='Alice', age=21, major='Computer Science', GPA=3.8)
# Out:
# name: Alice
# age: 21
# major: Computer Science
# GPA: 3.8

# %%
# classes
